# %%
import h5py
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy

filename = 'trial.h5'
# Out:
# Keys: KeysView(<HDF5 file "trial.h5" (mode r+)>)

# %%
df=pd.read_hdf(filename)
df.columns=df.columns.droplevel(0)

# %%
df.keys()
# Out:
# MultiIndex(levels=[['Elbow1', 'Elbow2', 'Elbow3', 'Fingera1', 'Fingera2', 'Fingera3', 'Fingerb1', 'Fingerb2', 'Fingerb3', 'Fingerc1', 'Fingerc2', 'Fingerc3', 'Fingerd1', 'Fingerd2', 'Fingerd3', 'Handle1', 'Handle2', 'Handle3', 'Palm1', 'Palm2', 'Palm3', 'Wristl1', 'Wristl2', 'Wristl3', 'Wristr1', 'Wristr2', 'Wristr3'], ['likelihood', 'x', 'y']],
#            labels=[[3, 3, 3, 6, 6, 6, 9, 9, 9, 12, 12, 12, 18, 18, 18, 24, 24, 24, 21, 21, 21, 0, 0, 0, 15, 15, 15, 4, 4, 4, 7, 7, 7, 10, 10, 10, 13, 13, 13, 19, 19, 19, 25, 25, 25, 22, 22, 22, 1, 1, 1, 16, 16, 16, 5, 5, 5, 8, 8, 8, 11, 11, 11, 14, 14, 14, 20, 20, 20, 26, 26, 26, 23, 23, 23, 2, 2, 2, 17, 17, 17], [1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0]],
#            names=['bodyparts', 'coords'])

# %%
finger=df.loc[:, df.columns.get_level_values(0).isin(['Wristr2'])]   #
finger
# Out:
# bodyparts      Wristr2
# coords               x           y likelihood
# 0          1457.862954  605.411090   0.000393
# 1           906.841464  124.080806   0.000737
# 2           919.802157  121.810805   0.000335
# 3           920.370871  120.715031   0.001097
# 4           732.735772  344.591839   0.002484
# 5           737.881041  330.478711   0.009302
# 6           731.017934  334.615446   0.006061
# 7           730.680390  331.637680   0.001890
# 8           729.044211  330.897906   0.001379
# 9           920.313379  121.269560   0.000948
# 10          920.357912  121.310117   0.001101
# 11          920.276445  121.454937   0.001113
# 12          728.165860  329.022642   0.001490
# 13          920.210623  120.441681   0.000309
# 14          714.251201  329.574723   0.001189
# 15          713.000854  323.713013   0.000805
# 16          713.203939  326.405467   0.000664
# 17          713.181223  326.348066   0.001941
# 18          711.879145  321.986951   0.001412
# ...

# %%
#grp_cnt = df.groupby(['x','y','likelihood'])['x','y','likelihood'].count()
#finger.reindex()
#finger.keys()
#finger.columns.droplevel(1)
finger.keys()
#finger.reindex()
x=finger['Wristr2','x'].copy()
y=finger['Wristr2','y'].copy()
prob=finger['Wristr2','likelihood'].copy()
x,y,prob
prob
#grp_cnt
# Out:
# (0      1457.862954
#  1       906.841464
#  2       919.802157
#  3       920.370871
#  4       732.735772
#  5       737.881041
#  6       731.017934
#  7       730.680390
#  8       729.044211
#  9       920.313379
#  10      920.357912
#  11      920.276445
#  12      728.165860
#  13      920.210623
#  14      714.251201
#  15      713.000854
#  16      713.203939
#  17      713.181223
#  18      711.879145
#  19      712.035142
#  20      708.256423
#  21      698.459214
#  22     1817.039881
#  23     1816.579498
#  24      708.655890
#  25      708.554541
#  26      713.920995
#  27      713.452815
#  28      713.193877
#  29      715.500558
#            ...
#  226     620.503906
#  227     790.473128
#  228     628.243890
#  229     627.890570
#  230     625.941561
#  231     623.715774
#  232     621.801809
#  233     619.942734
#  234     613.981033
#  235     614.985980
#  236     614.660500
#  237     811.783823
#  238     812.165087
#  239     812.231412
# ...

# %%
x_w=[]
y_w=[]
for i in range(0, len(x)):
    if prob.iloc[i] > .95:
        y_w.append(y.iloc[i])
        x_w.append(x.iloc[i])
    
print(y_w,x_w)
#wrist=wrist.loc[:, df.columns.get_level_values(0).isin(['x','y','likelihood'])]
#wrist
# Out:
# [449.710036277771, 435.09823352098465, 419.4998039007187, 401.0429666042328, 386.60397458076477, 377.09500074386597, 369.5895059108734, 359.50898575782776, 353.9274046421051, 348.2620811164379, 340.10562366992235, 333.08476305007935, 325.7751669883728, 317.81651878356934, 308.47496497631073, 300.4777551293373, 292.7560291290283, 284.0569331459701, 278.07477951049805, 271.9870409965515, 267.1422243118286, 264.90893602371216, 264.43506050109863, 264.6162714958191, 267.46572905778885, 269.7308152914047, 273.8505003452301, 284.6550057530403, 292.27697253227234, 308.6344811320305, 321.80496740341187, 336.4992456436157, 341.9625002145767, 347.7544211894274, 345.25583600997925, 338.04981994628906, 326.87844824790955, 318.74144172668457, 312.84259939193726, 306.59440660476685, 294.55655002593994, 283.26369392871857, 267.75347931683064, 253.5369050502777, 245.0183413028717, 240.81755781173706, 239.24215650558472, 239.70659685134888, 240.19475197792053, 242.13649117946625, 244.05833351239562, 
# ...

# %%
comp_time=np.linspace(0,len(y_w),len(y_w))
wrist_fig=sns.scatterplot(x_w,y_w).set_title('Right Wrist 2 tracked across entire video (P=.95)')
plt.xlabel('Pixels')
plt.ylabel('Pixels')
wrist_fig.figure.savefig("output.png")

# %%
plt.savefig('WristR2Trajectory.png')

# %%
Elbow1=df.loc[:, df.columns.get_level_values(0).isin(['Elbow1'])]
xE1=Elbow1['Elbow1','x'].copy()
yE1=Elbow1['Elbow1','y'].copy()
probE1=Elbow1['Elbow1','likelihood'].copy()
x_E1=[]
y_E1=[]
for i in range(0, len(xE1)):
    if probE1.iloc[i] > .9:
        y_E1.append(yE1.iloc[i])
        x_E1.append(xE1.iloc[i])
Elbow1_fig=sns.scatterplot(x_E1,y_E1).set_title('Elbow1 tracked across entire video (P=.9)')
plt.xlabel('Pixels')
plt.ylabel('Pixels')
#Elbow1_fig.set(xlabel='Pixels (x)', ylabel='Pixels(y)')
#Elbow_fig.title('Trajectory of Elbow1 from Trial Data')
Elbow1_fig.figure.savefig("Elbow1Trajectory.png")

# %%
Elbow2=df.loc[:, df.columns.get_level_values(0).isin(['Elbow2'])]
xE2=Elbow2['Elbow2','x'].copy()
yE2=Elbow2['Elbow2','y'].copy()
probE2=Elbow2['Elbow2','likelihood'].copy()
x_E2=[]
y_E2=[]
for i in range(0, len(xE2)):
    if probE2.iloc[i] > .9:
        y_E2.append(yE2.iloc[i])
        x_E2.append(xE2.iloc[i])
Elbow2_fig=sns.scatterplot(x_E2,y_E2).set_title('Elbow2 tracked across entire video (P=.9)')
plt.xlabel('Pixels')
plt.ylabel('Pixels')
#Elbow2_fig.set(xlabel='Pixels (x)', ylabel='Pixels(y)')
#Elbow_fig.title('Trajectory of Elbow1 from Trial Data')
Elbow2_fig.figure.savefig("Elbow2Trajectory_.9.png")

# %%
Elbow3=df.loc[:, df.columns.get_level_values(0).isin(['Elbow3'])]
xE3=Elbow3['Elbow3','x'].copy()
yE3=Elbow3['Elbow3','y'].copy()
probE3=Elbow3['Elbow3','likelihood'].copy()
x_E3=[]
y_E3=[]
for i in range(0, len(xE3)):
    if probE3.iloc[i] > .9:
        y_E3.append(yE3.iloc[i])
        x_E3.append(xE3.iloc[i])
Elbow2_fig=sns.scatterplot(x_E3,y_E3).set_title('Elbow3 tracked across entire video (P=.9)')
plt.xlabel('Pixels')
plt.ylabel('Pixels')
#Elbow2_fig.set(xlabel='Pixels (x)', ylabel='Pixels(y)')
#Elbow_fig.title('Trajectory of Elbow1 from Trial Data')
Elbow2_fig.figure.savefig("Elbow3Trajectory_.9.png")

# %%
# Single dimension against time kinematics for elbow
# use comp_time array as linspace frame
comp_time=np.linspace(0,len(x_E3),len(x_E3))
Elbow2_fig_x=sns.scatterplot(comp_time,x_E3).set_title('Elbow3 tracked across entire video (P=.9) in 1D for x position')
plt.xlabel('Frames')
plt.ylabel('Pixels')
Elbow2_fig_x.figure.savefig('Elbow3XTrajectory.png')

# %%
Elbow2_fig_y=sns.scatterplot(comp_time,y_E3).set_title('Elbow3 tracked across entire video (P=.9) in 1D for y position')
plt.xlabel('Frames')
plt.ylabel('Pixels')
Elbow2_fig_x.figure.savefig('Elbow3YTrajectory.png')

# %%
comp_time=np.linspace(0,len(x_E2),len(x_E2))
Elbow2_fig_x=sns.scatterplot(comp_time,x_E2).set_title('Elbow3 tracked across entire video (P=.9) in 1D for x position')
plt.xlabel('Frames')
plt.ylabel('Pixels')

Elbow2_fig_x.figure.savefig('Elbow2XTrajectory.png')

# %%
Elbow2_fig_y=sns.scatterplot(comp_time,y_E2).set_title('Elbow3 tracked across entire video (P=.9) in 1D for y position')
plt.xlabel('Frames')
plt.ylabel('Pixels')

Elbow2_fig_x.figure.savefig('Elbow2YTrajectory.png')

# %%
comp_time=np.linspace(0,len(x_E1),len(x_E1))
Elbow1_fig_x=sns.scatterplot(comp_time,x_E1).set_title('Elbow1 tracked across entire video (P=.9) in 1D for x position')
plt.xlabel('Frames')
plt.ylabel('Pixels')

Elbow1_fig_x.figure.savefig('Elbow1XTrajectory.png')

# %%
Elbow2_fig_y=sns.scatterplot(comp_time,y_E1).set_title('Elbow3 tracked across entire video (P=.9) in 1D for y position')
plt.xlabel('Frames')
plt.ylabel('Pixels')

Elbow2_fig_x.figure.savefig('Elbow1YTrajectory.png')

# %%
Wristr1=df.loc[:, df.columns.get_level_values(0).isin(['Wristr1'])]
x_wr1=Wristr1['Wristr1','x'].copy()
y_wr1=Wristr1['Wristr1','y'].copy()
prob_wr1=Wristr1['Wristr1','likelihood'].copy()
x_1=[]
y_1=[]
for i in range(0, len(x_wr1)):
    if prob_wr1.iloc[i] > .95:
        y_1.append(y_wr1.iloc[i])
        x_1.append(x_wr1.iloc[i])
Elbow1_fig=sns.scatterplot(x_1,y_1).set_title('Right wrist 1 tracked across entire video (P=.95)')
plt.xlabel('Pixels')
plt.ylabel('Pixels')
#Elbow1_fig.set(xlabel='Pixels (x)', ylabel='Pixels(y)')
#Elbow_fig.title('Trajectory of Elbow1 from Trial Data')
Elbow1_fig.figure.savefig("WristR1Trajectory.png")

# %%
Wristr3=df.loc[:, df.columns.get_level_values(0).isin(['Wristr3'])]
x_wr3=Wristr3['Wristr3','x'].copy()
y_wr3=Wristr3['Wristr3','y'].copy()
prob_wr3=Wristr3['Wristr3','likelihood'].copy()
x_3=[]
y_3=[]
for i in range(0, len(x_wr3)):
    if prob_wr3.iloc[i] > .9:
        y_3.append(y_wr3.iloc[i])
        x_3.append(x_wr3.iloc[i])
Elbow1_fig=sns.scatterplot(x_3,y_3).set_title('Right wrist 3 tracked across entire video (P=.95)')
plt.xlabel('Pixels')
plt.ylabel('Pixels')
#Elbow1_fig.set(xlabel='Pixels (x)', ylabel='Pixels(y)')
#Elbow_fig.title('Trajectory of Elbow1 from Trial Data')
Elbow1_fig.figure.savefig("WristR3Trajectory.png")

# %%
comp_time=np.linspace(0,len(x_3),len(x_3))
Elbow1_fig_x=sns.scatterplot(comp_time,x_3).set_title('Right Wrist 3 tracked across entire video (P=.95) in 1D for x position')
plt.xlabel('Frames')
plt.ylabel('Pixels')

Elbow1_fig_x.figure.savefig('WristR3XTrajectory.png')

# %%
Elbow1_fig_x=sns.scatterplot(comp_time,y_3).set_title('Right Wrist 3 tracked across entire video (P=.95) in 1D for y position')
plt.xlabel('Frames')
plt.ylabel('Pixels')

Elbow1_fig_x.figure.savefig('WristR3YTrajectory.png')

# %%
comp_time=np.linspace(0,len(x_1),len(x_1))
Elbow1_fig_x=sns.scatterplot(comp_time,x_1).set_title('Right Wrist 1 tracked across entire video (P=.95) in 1D for x position')
plt.xlabel('Frames')
plt.ylabel('Pixels')

Elbow1_fig_x.figure.savefig('WristR1XTrajectory.png')

# %%
Elbow1_fig_x=sns.scatterplot(comp_time,y_1).set_title('Right Wrist 3 tracked across entire video (P=.95) in 1D for y position')
plt.xlabel('Frames')
plt.ylabel('Pixels')

Elbow1_fig_x.figure.savefig('WristR1YTrajectory.png')

# %%
comp_time=np.linspace(0,len(y_w),len(y_w))
Elbow1_fig_x=sns.scatterplot(comp_time,x_w).set_title('Right Wrist 1 tracked across entire video (P=.95) in 1D for x position')
plt.xlabel('Frames')
plt.ylabel('Pixels')

Elbow1_fig_x.figure.savefig('WristR2XTrajectory.png')

# %%
Elbow1_fig_x=sns.scatterplot(comp_time,y_w).set_title('Right Wrist 2 tracked across entire video (P=.95) in 1D for y position')
plt.xlabel('Frames')
plt.ylabel('Pixels')

Elbow1_fig_x.figure.savefig('WristR2YTrajectory.png')

# %%
FB3=df.loc[:, df.columns.get_level_values(0).isin(['Fingerb3'])]
x_fb3=FB3['Fingerb3','x'].copy()
y_fb3=FB3['Fingerb3','y'].copy()
prob_fb3=FB3['Fingerb3','likelihood'].copy()
xfb_3=[]
yfb_3=[]
for i in range(0, len(x_fb3)):
    if prob_fb3.iloc[i] > .95:
        yfb_3.append(y_fb3.iloc[i])
        xfb_3.append(x_fb3.iloc[i])
Elbow1_fig=sns.scatterplot(xfb_3,yfb_3).set_title('Digit b from camera 3 tracked across entire video (P=.95)')
plt.xlabel('Pixels')
plt.ylabel('Pixels')
#Elbow1_fig.set(xlabel='Pixels (x)', ylabel='Pixels(y)')
#Elbow_fig.title('Trajectory of Elbow1 from Trial Data')
Elbow1_fig.figure.savefig("FB3Trajectory.png")

# %%
FB2=df.loc[:, df.columns.get_level_values(0).isin(['Fingerb2'])]
x_fb2=FB2['Fingerb2','x'].copy()
y_fb2=FB2['Fingerb2','y'].copy()
prob_fb2=FB2['Fingerb2','likelihood'].copy()
xfb_2=[]
yfb_2=[]
for i in range(0, len(x_fb2)):
    if prob_fb2.iloc[i] > .95:
        yfb_2.append(y_fb2.iloc[i])
        xfb_2.append(x_fb2.iloc[i])
Elbow1_fig=sns.scatterplot(xfb_2,yfb_2).set_title('Digit b from camera 2 tracked across entire video (P=.95)')
plt.xlabel('Pixels')
plt.ylabel('Pixels')
#Elbow1_fig.set(xlabel='Pixels (x)', ylabel='Pixels(y)')
#Elbow_fig.title('Trajectory of Elbow1 from Trial Data')
Elbow1_fig.figure.savefig("FB2Trajectory.png")

# %%
FB1=df.loc[:, df.columns.get_level_values(0).isin(['Fingerb1'])]
x_fb1=FB1['Fingerb1','x'].copy()
y_fb1=FB1['Fingerb1','y'].copy()
prob_fb1=FB1['Fingerb1','likelihood'].copy()
xfb_1=[]
yfb_1=[]
for i in range(0, len(x_fb1)):
    if prob_fb1.iloc[i] > .95:
        yfb_1.append(y_fb1.iloc[i])
        xfb_1.append(x_fb1.iloc[i])
Elbow1_fig=sns.scatterplot(xfb_1,yfb_1).set_title('Digit b from camera 1 tracked across entire video (P=.95)')
plt.xlabel('Pixels')
plt.ylabel('Pixels')
#Elbow1_fig.set(xlabel='Pixels (x)', ylabel='Pixels(y)')
#Elbow_fig.title('Trajectory of Elbow1 from Trial Data')
Elbow1_fig.figure.savefig("FB1Trajectory.png")

# %%
comp_time=np.linspace(0,len(y_fb1),len(y_fb1))
FB1_fig_x=sns.scatterplot(comp_time,x_fb1).set_title('Digit b from camera 1 tracked across entire video (P=.95) in 1D for x position')
plt.xlabel('Frames')
plt.ylabel('Pixels')

FB1_fig_x.figure.savefig('FB1XTrajectory.png')

# %%
Elbow1_fig_x=sns.scatterplot(comp_time,y_fb1).set_title('Digit b from camera 1 tracked across entire video (P=.95) in 1D for y position')
plt.xlabel('Frames')
plt.ylabel('Pixels')

Elbow1_fig_x.figure.savefig('FB1YTrajectory.png')

# %%
comp_time=np.linspace(0,len(y_fb2),len(y_fb2))
FB1_fig_x=sns.scatterplot(comp_time,x_fb2).set_title('Digit b from camera 2 tracked across entire video (P=.95) in 1D for x position')
plt.xlabel('Frames')
plt.ylabel('Pixels')

FB1_fig_x.figure.savefig('FB2XTrajectory.png')

# %%
Elbow1_fig_x=sns.scatterplot(comp_time,y_fb2).set_title('Digit b from camera 2 tracked across entire video (P=.95) in 1D for y position')
plt.xlabel('Frames')
plt.ylabel('Pixels')

Elbow1_fig_x.figure.savefig('FB2YTrajectory.png')

# %%
comp_time=np.linspace(0,len(y_fb3),len(y_fb3))
FB1_fig_x=sns.scatterplot(comp_time,x_fb3).set_title('Digit b from camera 3 tracked across entire video (P=.95) in 1D for x position')
plt.xlabel('Frames')
plt.ylabel('Pixels')

FB1_fig_x.figure.savefig('FB3XTrajectory.png')

# %%
Elbow1_fig_x=sns.scatterplot(comp_time,y_fb3).set_title('Digit b from camera 3 tracked across entire video (P=.95) in 1D for y position')
plt.xlabel('Frames')
plt.ylabel('Pixels')

Elbow1_fig_x.figure.savefig('FB3YTrajectory.png')

# %%
Palm1=df.loc[:, df.columns.get_level_values(0).isin(['Palm1'])]
x_p1=Palm1['Palm1','x'].copy()
y_p1=Palm1['Palm1','y'].copy()
prob_p1=Palm1['Palm1','likelihood'].copy()
xp_1=[]
yp_1=[]
for i in range(0, len(x_p1)):
    if prob_p1.iloc[i] > .95:
        yp_1.append(y_p1.iloc[i])
        xp_1.append(x_p1.iloc[i])
Elbow1_fig=sns.scatterplot(xp_1,yp_1).set_title('Palm from camera 1 tracked across entire video (P=.95)')
plt.xlabel('Pixels')
plt.ylabel('Pixels')
#Elbow1_fig.set(xlabel='Pixels (x)', ylabel='Pixels(y)')
#Elbow_fig.title('Trajectory of Elbow1 from Trial Data')
Elbow1_fig.figure.savefig("Palm1Trajectory.png")

# %%
Palm2=df.loc[:, df.columns.get_level_values(0).isin(['Palm2'])]
x_p2=Palm2['Palm2','x'].copy()
y_p2=Palm2['Palm2','y'].copy()
prob_p2=Palm2['Palm2','likelihood'].copy()
xp_2=[]
yp_2=[]
for i in range(0, len(x_p2)):
    if prob_p2.iloc[i] > .95:
        yp_2.append(y_p2.iloc[i])
        xp_2.append(x_p2.iloc[i])
Elbow1_fig=sns.scatterplot(xp_2,yp_2).set_title('Palm from camera 2 tracked across entire video (P=.95)')
plt.xlabel('Pixels')
plt.ylabel('Pixels')
#Elbow1_fig.set(xlabel='Pixels (x)', ylabel='Pixels(y)')
#Elbow_fig.title('Trajectory of Elbow1 from Trial Data')
Elbow1_fig.figure.savefig("Palm2Trajectory.png")

# %%
Palm3=df.loc[:, df.columns.get_level_values(0).isin(['Palm3'])]
x_p3=Palm3['Palm3','x'].copy()
y_p3=Palm3['Palm3','y'].copy()
prob_p3=Palm3['Palm3','likelihood'].copy()
xp_3=[]
yp_3=[]
for i in range(0, len(x_p3)):
    if prob_p3.iloc[i] > .95:
        yp_3.append(y_p3.iloc[i])
        xp_3.append(x_p3.iloc[i])
Elbow1_fig=sns.scatterplot(xp_3,yp_3).set_title('Palm from camera 3 tracked across entire video (P=.95)')
plt.xlabel('Pixels')
plt.ylabel('Pixels')
#Elbow1_fig.set(xlabel='Pixels (x)', ylabel='Pixels(y)')
#Elbow_fig.title('Trajectory of Elbow1 from Trial Data')
Elbow1_fig.figure.savefig("Palm3Trajectory.png")

# %%
# Now let's make multi-layered plots for each camera
# I want to take each representation, plot it for each camera
# I need: Wristr, Palm, Digit, Elbow
#palette = sns.color_palette("bright", 4)  #Choosing color
fig, ax1 = plt.subplots()
ax1.scatter(xp_3,yp_3, c='red', label = 'Palm')
ax1.scatter(x_fb3,y_fb3, c='blue', label = 'Digit')
ax1.scatter(x_wr3,y_wr3, c='orange', label = 'Wrist')
ax1.scatter(x_E3,y_E3, c='black', label = 'Elbow')
plt.xlabel('Pixels')
plt.ylabel('Pixels')
plt.title('Camera 3: Reach Representation (P=.95)')
plt.legend()
plt.savefig('Camera3ReachTotal.png')

# %%
fig, ax1 = plt.subplots()
ax1.scatter(xp_2,yp_2, c='red', label = 'Palm')
ax1.scatter(x_fb2,y_fb2, c='blue', label = 'Digit')
ax1.scatter(x_w,y_w, c='orange', label = 'Wrist')
ax1.scatter(x_E2,y_E2, c='black', label = 'Elbow')
plt.xlabel('Pixels')
plt.ylabel('Pixels')
plt.title('Camera 2: Reach Representation (P=.95)')
plt.legend()
plt.savefig('Camera2ReachTotal.png')

# %%
fig, ax1 = plt.subplots()
ax1.scatter(xp_1,yp_1, c='red', label = 'Palm')
ax1.scatter(x_fb1,y_fb1, c='blue', label = 'Digit')
ax1.scatter(x_wr1,y_wr1, c='orange', label = 'Wrist')
ax1.scatter(x_E1,y_E1, c='black', label = 'Elbow')
plt.xlabel('Pixels')
plt.ylabel('Pixels')
plt.title('Camera 1: Reach Representation (P=.95)')
plt.legend()
plt.savefig('Camera1ReachTotal.png')

# %%
# Finally, let's reconstruct some 1-D plots for individual camera angles
timecourseb=np.linspace(0,len(y_fb3),len(y_fb3))
timecoursep=np.linspace(0,len(xp_1),len(xp_1))
timecoursew=np.linspace(0,len(x_wr1),len(x_wr1))
timecoursee=np.linspace(0,len(x_E1),len(x_E1))
fig, ax1 = plt.subplots()
ax1.scatter(timecoursep,xp_1,c='red',label='Palm (x)')
ax1.scatter(timecourseb,x_fb1, c='blue', label = 'Digit')
ax1.scatter(timecoursew,x_wr1, c='orange', label = 'Wrist')
ax1.scatter(timecoursee,x_E1, c='black', label = 'Elbow')
plt.xlabel('Frames')
plt.ylabel('Pixels')
plt.title('Camera 1: Reach Representation in X (P=.95)')
plt.legend()
plt.savefig('Camera1ReachTotalX.png')

# %%
timecourseb=np.linspace(0,len(y_fb2),len(y_fb2))
timecoursep=np.linspace(0,len(xp_2),len(xp_2))
timecoursew=np.linspace(0,len(x_w),len(x_w))
timecoursee=np.linspace(0,len(x_E2),len(x_E2))
fig, ax1 = plt.subplots()
ax1.scatter(timecoursep,xp_2,c='red',label='Palm (x)')
ax1.scatter(timecourseb,x_fb2, c='blue', label = 'Digit')
ax1.scatter(timecoursew,x_w, c='orange', label = 'Wrist')
ax1.scatter(timecoursee,x_E2, c='black', label = 'Elbow')
plt.xlabel('Frames')
plt.ylabel('Pixels')
plt.title('Camera 2: Reach Representation in X (P=.95)')
plt.legend()
plt.savefig('Camera2ReachTotalX.png')

# %%
timecourseb=np.linspace(0,len(y_fb3),len(y_fb3))
timecoursep=np.linspace(0,len(xp_3),len(xp_3))
timecoursew=np.linspace(0,len(x_wr3),len(x_wr3))
timecoursee=np.linspace(0,len(x_E3),len(x_E3))
fig, ax1 = plt.subplots()
ax1.scatter(timecoursep,xp_3,c='red',label='Palm (x)')
ax1.scatter(timecourseb,x_fb3, c='blue', label = 'Digit')
ax1.scatter(timecoursew,x_wr3, c='orange', label = 'Wrist')
ax1.scatter(timecoursee,x_E3, c='black', label = 'Elbow')
plt.xlabel('Frames')
plt.ylabel('Pixels')
plt.title('Camera 3: Reach Representation in X (P=.95)')
plt.legend()
plt.savefig('Camera3ReachTotalX.png')

# %%
timecourseb=np.linspace(0,len(y_fb3),len(y_fb3))
timecoursep=np.linspace(0,len(xp_1),len(xp_1))
timecoursew=np.linspace(0,len(x_wr1),len(x_wr1))
timecoursee=np.linspace(0,len(x_E1),len(x_E1))
fig, ax1 = plt.subplots()
ax1.scatter(timecoursep,yp_1,c='red',label='Palm (y)')
ax1.scatter(timecourseb,y_fb1, c='blue', label = 'Digit')
ax1.scatter(timecoursew,y_wr1, c='orange', label = 'Wrist')
ax1.scatter(timecoursee,y_E1, c='black', label = 'Elbow')
plt.xlabel('Frames')
plt.ylabel('Pixels')
plt.title('Camera 1: Reach Representation in Y (P=.95)')
plt.legend()
plt.savefig('Camera1ReachTotalY.png')

# %%
timecourseb=np.linspace(0,len(y_fb3),len(y_fb3))
timecoursep=np.linspace(0,len(xp_3),len(xp_3))
timecoursew=np.linspace(0,len(x_wr3),len(x_wr3))
timecoursee=np.linspace(0,len(x_E3),len(x_E3))
fig, ax1 = plt.subplots()
ax1.scatter(timecoursep,yp_3,c='red',label='Palm (y)')
ax1.scatter(timecourseb,y_fb3, c='blue', label = 'Digit')
ax1.scatter(timecoursew,y_wr3, c='orange', label = 'Wrist')
ax1.scatter(timecoursee,y_E3, c='black', label = 'Elbow')
plt.xlabel('Frames')
plt.ylabel('Pixels')
plt.title('Camera 3: Reach Representation in Y (P=.95)')
plt.legend()
plt.savefig('Camera3ReachTotalY.png')

# %%
timecourseb=np.linspace(0,len(y_fb2),len(y_fb2))
timecoursep=np.linspace(0,len(xp_2),len(xp_2))
timecoursew=np.linspace(0,len(x_w),len(x_w))
timecoursee=np.linspace(0,len(x_E2),len(x_E2))
fig, ax1 = plt.subplots()
ax1.scatter(timecoursep,yp_2,c='red',label='Palm (x)')
ax1.scatter(timecourseb,y_fb2, c='blue', label = 'Digit')
ax1.scatter(timecoursew,y_w, c='orange', label = 'Wrist')
ax1.scatter(timecoursee,y_E2, c='black', label = 'Elbow')
plt.xlabel('Frames')
plt.ylabel('Pixels')
plt.title('Camera 2: Reach Representation in Y (P=.95)')
plt.legend()
plt.savefig('Camera2ReachTotalY.png')
