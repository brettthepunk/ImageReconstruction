# %%
import Rec
import os
owd = os.getcwd()

# %%
int_crn_x = 9
int_crn_y = 9
img_dir_name = 'Cal_a'
img_dir = owd + '/' + img_dir_name + '/'

Rec.calc_calibration(img_dir,(int_crn_x, int_crn_y), save = True, savename=img_dir_name)
# Out:
# (0.878179888284536, array([[1.93147770e+03, 0.00000000e+00, 9.29248416e+02],
#         [0.00000000e+00, 1.90156164e+03, 7.49914824e+02],
#         [0.00000000e+00, 0.00000000e+00, 1.00000000e+00]]), array([[-4.44722027e-01,  1.40781403e+00, -2.90644311e-03,
#           4.82822960e-04, -2.22960329e+00]]), [array([[ 0.64808332],
#          [-0.31752842],
#          [ 0.14218017]]), array([[ 0.49252897],
#          [-0.2929446 ],
#          [ 0.16399814]]), array([[ 0.47067851],
#          [-0.02888669],
#          [ 0.28545898]]), array([[ 0.7142498 ],
#          [-0.49036431],
#          [ 0.19467082]]), array([[ 0.37159424],
#          [-0.0755036 ],
#          [ 0.43057695]]), array([[ 0.16359291],
#          [-0.8160923 ],
#          [ 0.50839962]]), array([[ 0.21061909],
#          [-0.45471666],
#          [ 0.42486632]]), array([[ 0.35335647],
#          [-0.30997884],
#          [ 0.34349563]]), array([[0.67680869],
#          [0.39375118],
# ...
